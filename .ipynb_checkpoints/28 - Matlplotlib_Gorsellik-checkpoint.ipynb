# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
(benimFigur, benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,"#3A95A8",alpha=0.3)
benimEksen.plot(numpyDizisi2,numpyDizisi1,"#C96F23")
# Renkler HEX kodunda. İnternetten, istenilen ara renk kolayca bulunabilir.
# alpha=0.3 ise saydamlık katsayısı

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 2, color="blue", linewidth = 8.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 3, color="yellow", linewidth = 4.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 4, color="black", linestyle = "-.")
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 5, color="red", linestyle = ":", marker = "+")
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 6, color="green", linestyle = "--", marker = "o")

# linewidth kalınlık için, linestyle stil, marker da üzerine eklenecek desen

# %% [markdown]
# # scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# # histogram

# %%
yeniDizi = np.random.randint(0,100,80)

# %%
yeniDizi
# Out:
# array([83, 83,  9, 57, 33, 12, 43, 43, 37, 37, 75, 94, 75, 86, 90, 52, 48,
#        32, 50, 76, 53, 95, 26, 64, 93, 83, 94, 87, 58, 73, 35, 38, 44, 63,
#        26, 32, 71, 35, 81, 75, 50, 69, 79, 84, 81, 94, 51, 55, 97, 16,  3,
#        35, 83,  0, 36, 50, 37, 30, 73, 54, 65, 15, 30, 15, 35, 63, 65, 26,
#        56, 21, 20, 54, 55, 77, 53, 30, 73, 42,  7, 66])

# %%
plt.hist(yeniDizi)
# Out:
# (array([ 4.,  4.,  5., 15.,  5., 14.,  6., 10., 10.,  7.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17902861350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x179028629d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x179028b8c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1790281ad90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17902819e90>],
#  'means': []}

# %%
plt.boxplot(yeniDizi*3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x179027e5610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17902826ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17902824cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x179027ec410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x179027eced0>],
#  'means': []}
